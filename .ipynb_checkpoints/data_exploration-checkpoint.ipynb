# %%
DATA_DIR = "../data"

# %%
import pandas as pd

df = pd.read_csv(f"{DATA_DIR}/raw/results.csv")

display(df.head())
display(df.describe())
# Out:
#    Unnamed: 0        date               team_1          team_2     _map  \
# 0           0  2020-03-18              Recon 5         TeamOne    Dust2
# 1           1  2020-03-18              Recon 5         TeamOne  Inferno
# 2           2  2020-03-18  New England Whalers        Station7  Inferno
# 3           3  2020-03-18              Rugratz  Bad News Bears  Inferno
# 4           4  2020-03-18              Rugratz  Bad News Bears  Vertigo
#
#    result_1  result_2  map_winner  starting_ct  ct_1  t_2  t_1  ct_2  \
# 0         0        16           2            2     0    1    0    15
# 1        13        16           2            2     8    6    5    10
# 2        12        16           2            1     9    6    3    10
# 3         7        16           2            2     0    8    7     8
# 4         8        16           2            2     4    5    4    11
#
#    event_id  match_id  rank_1  rank_2  map_wins_1  map_wins_2  match_winner
# ...
