# %%
DATA_DIR = "../data"

# %%
import pandas as pd

df = pd.read_csv(f"{DATA_DIR}/raw/results.csv")

display(df.head())
display(df.describe())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2
#       3 df = pd.read_csv(f"{DATA_DIR}/raw/results.csv")
#       4
#
# ModuleNotFoundError: No module named 'pandas'
